# %%
# IMPORTING LIBRARIES

import numpy as np
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Load the data

dataset_sales=pd.read_csv('Advertising.csv')
dataset_sales.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
# Visualization of dataset (stats)

dataset_sales.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
dataset_sales.shape
# Out:
# (200, 5)

# %%
dataset_sales.columns.values.tolist()
# Out:
# ['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales']

# %%
# Basic information about data types

dataset_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
# Preprocessing ( Checking for null values)

dataset_sales.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
dataset_sales.duplicated().sum()
# Out:
# 0

# %%
sns.countplot(x='Sales',data=dataset_sales)
plt.show()

# %%
sns.pairplot(hue='Sales',height=2,data=dataset_sales)

# %%
dataset_sales.corr()
# Out:
#             Unnamed: 0        TV     Radio  Newspaper     Sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# Radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# Newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# Sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
sns.heatmap(dataset_sales.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(dataset_sales,kind="reg",corner=True)

# %%
fig, axs =plt.subplots(3,figsize=(5,5))
plt1 = sns.boxplot(dataset_sales['TV'], ax= axs[0])
plt2 = sns.boxplot(dataset_sales['Newspaper'], ax= axs[1])
plt3 = sns.boxplot(dataset_sales['Radio'], ax= axs[2])
plt.tight_layout()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.displot(dataset_sales['Newspaper'])

# %%
iqr=dataset_sales.Newspaper.quantile(0.75)-dataset_sales.Newspaper.quantile(0.25)
lower=dataset_sales["Newspaper"].quantile(0.25)-(iqr*1.5)
upper=dataset_sales["Newspaper"].quantile(0.75)+(iqr*1.5)
print(lower)
print(upper)
# Out:
# -35.775000000000006
# 93.625

# %%
data=dataset_sales.copy()

# %%
X= data['TV']
Y= data['Sales']

# %%
X=X.values.reshape(-1,1)

# %%
X
# Out:
# array([[230.1],
#        [ 44.5],
#        [ 17.2],
#        [151.5],
#        [180.8],
#        [  8.7],
#        [ 57.5],
#        [120.2],
#        [  8.6],
#        [199.8],
#        [ 66.1],
#        [214.7],
#        [ 23.8],
#        [ 97.5],
#        [204.1],
#        [195.4],
#        [ 67.8],
#        [281.4],
#        [ 69.2],
#        [147.3],
#        [218.4],
#        [237.4],
#        [ 13.2],
#        [228.3],
#        [ 62.3],
#        [262.9],
#        [142.9],
#        [240.1],
#        [248.8],
#        [ 70.6],
#        [292.9],
#        [112.9],
#        [ 97.2],
#        [265.6],
#        [ 95.7],
#        [290.7],
#        [266.9],
#        [ 74.7],
#        [ 43.1],
#        [228. ],
#        [202.5],
#        [177. ],
#        [293.6],
#        [206.9],
#        [ 25.1],
#        [175.1],
#        [ 89.7],
#        [239.9],
#        [227.2],
#        [ 66.9],
#        [199.8],
#        [100.4],
#        [216.4],
#        [182.6],
#        [262.7],
#        [198.9],
#        [  7.3],
#        [136.2],
#        [210.8],
#        [210.7],
#        [ 53.5],
#        [261.3],
#        [239.3],
#        [102.7],
#        [131.1],
#        [ 69. ],
#        [ 31.5],
#        [139.3],
#        [237.4],
#        [216.8],
#        [199.1],
#        [109.8],
#        [ 26.8],
#        [129.4],
#        [213.4],
#        [ 16.9],
#        [ 27.5],
#        [120.5],
#        [  5.4],
#        [116. ],
#        [ 76.4],
#        [239.8],
#        [ 75.3],
#        [ 68.4],
#        [213.5],
#        [193.2],
#        [ 76.3],
#        [110.7],
#        [ 88.3],
#        [109.8],
#        [134.3],
#        [ 28.6],
#        [217.7],
#        [250.9],
#        [107.4],
#        [163.3],
#        [197.6],
#        [184.9],
#        [289.7],
#        [135.2],
#        [222.4],
#        [296.4],
#        [280.2],
#        [187.9],
#        [238.2],
#        [137.9],
#        [ 25. ],
#        [ 90.4],
#        [ 13.1],
#        [255.4],
#        [225.8],
#        [241.7],
#        [175.7],
#        [209.6],
#        [ 78.2],
#        [ 75.1],
#        [139.2],
#        [ 76.4],
#        [125.7],
#        [ 19.4],
#        [141.3],
#        [ 18.8],
#        [224. ],
#        [123.1],
#        [229.5],
#        [ 87.2],
#        [  7.8],
#        [ 80.2],
#        [220.3],
#        [ 59.6],
#        [  0.7],
#        [265.2],
#        [  8.4],
#        [219.8],
#        [ 36.9],
#        [ 48.3],
#        [ 25.6],
#        [273.7],
#        [ 43. ],
#        [184.9],
#        [ 73.4],
#        [193.7],
#        [220.5],
#        [104.6],
#        [ 96.2],
#        [140.3],
#        [240.1],
#        [243.2],
#        [ 38. ],
#        [ 44.7],
#        [280.7],
#        [121. ],
#        [197.6],
#        [171.3],
#        [187.8],
#        [  4.1],
#        [ 93.9],
#        [149.8],
#        [ 11.7],
#        [131.7],
#        [172.5],
#        [ 85.7],
#        [188.4],
#        [163.5],
#        [117.2],
#        [234.5],
#        [ 17.9],
#        [206.8],
#        [215.4],
#        [284.3],
#        [ 50. ],
#        [164.5],
#        [ 19.6],
#        [168.4],
#        [222.4],
#        [276.9],
#        [248.4],
#        [170.2],
#        [276.7],
#        [165.6],
#        [156.6],
#        [218.5],
#        [ 56.2],
#        [287.6],
#        [253.8],
#        [205. ],
#        [139.5],
#        [191.1],
#        [286. ],
#        [ 18.7],
#        [ 39.5],
#        [ 75.5],
#        [ 17.2],
#        [166.8],
#        [149.7],
#        [ 38.2],
#        [ 94.2],
#        [177. ],
#        [283.6],
#        [232.1]])

# %%
print(X.shape,Y.shape)
# Out:
# (200, 1) (200,)

# %%
# splitting data for training and testing

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test=train_test_split(X,Y,test_size=0.3)

# %%
print(X_train.shape,Y_train.shape)
# Out:
# (140, 1) (140,)

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.neighbors import KNeighborsRegressor

# %%
knn =KNeighborsRegressor().fit(X_train,Y_train)
knn
# Out:
# KNeighborsRegressor()

# %%
knn_train_pred=knn.predict(X_train)
knn_test_pred=knn.predict(X_test)
print(knn_train_pred,knn_test_pred)
# Out:
# [16.84 15.1  20.68  5.88 16.06 18.98 10.9  16.34  9.96 10.76 17.48 11.72
#  11.28 16.64 18.54 16.32  9.96 16.06 14.6  13.22 12.44 13.04  4.44 16.32
#   4.44 14.98  9.78  7.72 16.32 15.6   6.82 18.72 18.1   9.84 11.66 19.36
#   6.28  8.86  8.86 19.9  16.34 10.74 15.76 11.98 17.8  15.76 12.78 11.42
#  16.98 13.22 17.92 10.74 11.42 16.06 16.18 17.04 18.54 19.9  10.9   9.96
#  11.42 10.06 17.04 13.88 20.68 18.22 16.52 16.72 14.02 16.52  6.26 18.72
#  16.06 13.5  12.38 10.56  5.08 18.44  6.28 13.5  17.8   9.96 20.14 10.7
#  13.88  9.34 17.8  16.06 15.5   8.22  7.14 13.3  18.34 19.36  9.82 15.2
#  15.36 16.64 11.72 12.7  11.98 11.28 10.76  6.82 17.46  6.04 20.38 17.48
#  11.28  9.78 20.78 11.28 11.42 18.98 18.94  6.82 18.92 13.5  15.94 16.34
#  18.72 14.6  12.66 13.22 11.1   9.84  6.26 19.36 14.68 20.14 12.66  5.88
#  16.32 16.32 16.52 16.64 18.92 19.36 16.84 12.7 ] [ 7.14 17.8   5.88 10.76 13.88 15.5  13.5  20.68 16.34  7.72  8.22  6.82
#  15.94  8.22  7.72 13.06 20.68  9.82 17.38 10.62 15.5   9.78 20.68 15.94
#  14.68 18.34 12.7  11.52 16.92 16.92 15.1  15.6   6.82 15.6  16.02 18.94
#  16.64 17.92 20.38  6.82 18.94 11.42 11.42 16.24 18.94 11.98 20.68 11.8
#  19.36  9.34 16.72 17.8   9.96 13.88 16.64 18.34 17.46  9.52 18.92 16.52]

# %%
r2= r2_score(Y_test,knn_test_pred)
r2_train = r2_score(Y_train,knn_train_pred)
rmse= np.sqrt(mean_squared_error(Y_test,knn_test_pred))
varience= r2_train -r2

print("K-Nearest Neighbors")
print("R2 TRAIN : ",r2_train)
print("R2 : ",r2)
print("RMSE : ",rmse)
print("VARIENCE : ",varience)
# Out:
# K-Nearest Neighbors
# R2 TRAIN :  0.6666538606374663
# R2 :  0.5862727105890988
# RMSE :  3.555759646920285
# VARIENCE :  0.08038115004836754

# %%
import statsmodels.api as sm

X_train_constant = sm.add_constant(X_train)
model = sm.OLS(Y_train, X_train_constant).fit()
model.params
# Out:
# const    7.135092
# x1       0.046380
# dtype: float64

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.590
# Model:                            OLS   Adj. R-squared:                  0.587
# Method:                 Least Squares   F-statistic:                     198.5
# Date:                Fri, 24 Feb 2023   Prob (F-statistic):           1.71e-28
# Time:                        15:09:26   Log-Likelihood:                -362.93
# No. Observations:                 140   AIC:                             729.9
# Df Residuals:                     138   BIC:                             735.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.1351      0.550     12.977      0.000       6.048       8.222
# x1             0.0464      0.003     14.089      0.000       0.040       0.053
# ==============================================================================
# Omnibus:                        0.702   Durbin-Watson:                   1.912
# Prob(Omnibus):                  0.704   Jarque-Bera (JB):                0.783
# Skew:                           0.032   Prob(JB):                        0.676
# Kurtosis:                       2.639   Cond. No.                         334.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
plt.scatter(X_train, Y_train)
plt.plot(X_train,6.995+0.0541*X_train)
plt.show()

# %%
Y_train_pred= model.predict(X_train_constant)
result= (Y_train - Y_train_pred)
result
# Out:
# 160   -0.735587
# 64     4.784531
# 98     4.828714
# 56    -1.973664
# 62    -2.533750
#          ...
# 102   -5.330679
# 20     0.735585
# 168   -0.025276
# 153    3.920068
# 89     4.472419
# Name: Sales, Length: 140, dtype: float64

# %%
Y_train_pred
# Out:
# array([15.13558734, 13.21546851, 20.57128606,  7.47366389, 18.23375009,
#        19.43498385, 10.76198333, 16.36928688,  9.20826399, 11.50405825,
#        15.5205387 , 10.59965445, 10.27963464, 16.09564675, 16.29971735,
#        14.87122315,  9.19898805, 18.27085383, 13.45200489, 12.74703372,
#        12.51513531, 13.53085034,  7.32524891, 14.7181702 ,  7.16755799,
#        12.96501823,  9.61640519,  8.29458426, 14.76454988, 17.35253613,
#         7.93282274, 17.70965968, 15.99824942, 11.64319729, 11.10983095,
#        20.28837   ,  7.53859544,  8.46155111,  8.59605219, 18.41463085,
#        16.36001094, 10.20078918, 18.01112762, 11.23041812, 16.60118529,
#        13.36388349, 12.3713583 , 10.62748226, 17.67255594, 12.72384388,
#        16.19768205, 10.23789293, 10.67849991, 18.2615779 , 19.82921115,
#        15.71069539, 16.29971735, 18.34506133, 10.8547427 ,  8.90679606,
#        10.63675819,  9.37523085, 15.71069539, 14.08276856, 20.71970104,
#        16.85627354, 18.14562869, 15.87302428, 12.84443105, 17.89981638,
#         7.74266604, 17.72357359, 18.27085383, 13.60505784, 12.57079093,
#        11.49014434,  7.38554249, 17.80705702,  7.53395747, 13.64216158,
#        16.5269778 ,  8.89752012, 18.98046297, 11.79161227, 14.16161402,
#         9.74163033, 19.96835019, 18.25693993, 15.28400232,  8.32241207,
#         8.04413398, 12.11627005, 19.25410309, 20.32083578,  9.1340565 ,
#        17.52414096, 17.60762438, 20.15386892, 10.53936086, 12.22758128,
#        11.32781545, 10.3445662 , 11.57362777,  7.96528852, 17.17165537,
#         7.67773449, 18.67435707, 15.60402213, 10.30746245,  8.84650247,
#        18.65580519, 10.33529026, 10.67849991, 19.45353572, 17.0371543 ,
#         8.00703023, 17.26905271, 13.59114393, 15.34429591, 16.40175265,
#        17.77922921, 13.4056252 , 13.68854126, 12.70992997, 11.89828554,
#        11.6571112 ,  7.74730401, 17.09280991, 17.44993347, 18.90625548,
#        13.76274875,  7.49685373, 14.70889426, 14.81556753, 18.14562869,
#        20.13067908, 17.26441474, 17.12527569, 15.07993172, 12.22758128])

# %%
figure= plt.figure()
sns.displot(result)
plt.show()

# %%
plt.scatter(X_train,result)
plt.show()

# %%
X_test_constant = sm.add_constant(X_test)
Y_pred = model.predict(X_test_constant)
Y_pred
# Out:
# array([ 8.03485804, 19.97762613,  7.52468154, 11.59681761, 14.07813059,
#        15.25617451, 13.5957819 , 20.75216682, 16.40175265,  8.23892864,
#         8.41053346,  7.93282274, 15.02891407,  8.37806768,  8.29922223,
#        11.98640694, 20.47388873,  9.12941853, 19.51382931, 10.02454639,
#        13.13662305,  9.45407631, 20.61766574, 15.34429591, 17.44993347,
#        19.32831058, 12.269323  , 10.40949775, 16.72641043, 16.7310484 ,
#        13.24329632, 14.3981504 ,  7.91890883, 17.36181207, 14.94543064,
#        16.90729119, 20.1863347 , 15.84519647, 18.7717544 ,  8.00239226,
#        16.91192916, 10.67386194, 10.61820632, 16.642927  , 17.03251633,
#        11.29534968, 20.88202993, 11.17940047, 20.39968123,  9.80192392,
#        15.84983444, 17.32934629,  8.96708965, 13.96681935, 16.11883659,
#        19.31903465, 17.19020725,  9.89932125, 17.23194896, 18.18273244])

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
np.sqrt(mean_squared_error(Y_test,Y_pred))
# Out:
# 3.271237510689012

# %%
r2= r2_score(Y_test,Y_pred)
r2
# Out:
# 0.6498343597375689

# %%
plt.scatter(X_test,Y_test)
plt.plot(X_test, 6.9955 + 0.0541*X_test)
plt.show()
